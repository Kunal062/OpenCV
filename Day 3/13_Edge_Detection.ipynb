# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r'D:\NLP\Day14\images\lenna.png',0)

# %%
# Sobel parameters : ksize ,dx,dy,depth
sobelx = cv2.Sobel(image,cv2.CV_64F,1,0,ksize=3)  # Sobel for Horizontal edges 
sobely = cv2.Sobel(image,cv2.CV_64F,0,1,ksize=3)  # Sobel for vertical edges 

# Combined the sobel images(Optional)
combined_sobel = cv2.add(sobelx,sobely)

# %%
thresh,binary_sobel = cv2.threshold(combined_sobel,100,255,cv2.THRESH_BINARY)

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,4,1)
plt.title('Original Image')
plt.imshow(image,cmap='gray')
plt.subplot(1,4,2)
plt.title('Sobel X')
plt.imshow(sobelx,cmap='gray')
plt.subplot(1,4,3)
plt.title('Sobel Y')
plt.imshow(sobely,cmap='gray')
plt.subplot(1,4,4)
plt.title('Final')
plt.imshow(binary_sobel,cmap='gray')

# %%
combined_sobel.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Combined Image

# %%
img1 = cv2.imread(r'D:\NLP\Day14\images\lenna.png')
img2 = cv2.imread(r'D:\NLP\Day14\images\sun.png')

# %%
img1.shape,img2.shape
# Out:
# ((512, 512, 3), (512, 512, 3))

# %%
new_img = cv2.add(img1,img2)
final_img = np.hstack([img1,img2,new_img])

# %%
cv2.imshow('Added Image',final_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Canny Edge Detection

# %%
img = cv2.imread(r'D:\NLP\Day14\images\lenna.png',0)

# Apply Canny edge detection

edges = cv2.Canny(img,50,150) # Adjust threshold if needed

# Display the image
cv2.imshow('Canny Edge Detetion',edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,3,1)
plt.title('Original Image')
plt.imshow(image,cmap='gray')
plt.subplot(1,3,2)
plt.title('Final Sobel')
plt.imshow(binary_sobel,cmap='gray')
plt.subplot(1,3,3)
plt.title('Canny')
plt.imshow(edges,cmap='gray')

# %%
img1 = cv2.imread(r'D:\NLP\Day14\images\circle.png',0)

# %%
# Sobel parameters : ksize ,dx,dy,depth
sobelx = cv2.Sobel(img1,cv2.CV_64F,1,0,ksize=3)  # Sobel for Horizontal edges 
sobely = cv2.Sobel(img1,cv2.CV_64F,0,1,ksize=3)  # Sobel for vertical edges 

# Combined the sobel images(Optional)
combined_sobel = cv2.add(sobelx,sobely)

thresh,binary_sobel = cv2.threshold(combined_sobel,100,255,cv2.THRESH_BINARY)

edges = cv2.Canny(img1,50,150) # Adjust threshold if needed

plt.figure(figsize=(16,8))
plt.subplot(1,3,1)
plt.title('Original Image')
plt.imshow(img1,cmap='gray')
plt.subplot(1,3,2)
plt.title('Final Sobel')
plt.imshow(binary_sobel,cmap='gray')
plt.subplot(1,3,3)
plt.title('Canny')
plt.imshow(edges,cmap='gray')

# %% [markdown]
# ## Harris Corner detector

# %%
import cv2
import numpy as np

# Load the image
gray = cv2.imread('../Day14/images/circle.png', 0)
image = cv2.imread('../Day14/images/circle.png')

# Convert image to float32
gray = np.float32(gray)

# Apply the Harris Corner detector
dst = cv2.cornerHarris(gray, blockSize=2, ksize=3, k=0.04)

# Result dilated for marking the corners, not important
dst = cv2.dilate(dst, None)

# Threshold for an optimal value, it may vary depending on the image.
image[dst > 0.01 * dst.max()] = [0, 0, 255]

# Display the result
cv2.imshow("Harris Cornes", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the image
gray = cv2.imread('../Day14/images/lenna.png', 0)
image = cv2.imread('../Day14/images/lenna.png')

# Convert image to float32
gray = np.float32(gray)

# Apply the Harris Corner detector
dst = cv2.cornerHarris(gray, blockSize=2, ksize=3, k=0.04)

# Result dilated for marking the corners, not important
dst = cv2.dilate(dst, None)78

# Threshold for an optimal value, it may vary depending on the image.
image[dst > 0.01 * dst.max()] = [0, 0, 255]

# Display the result
cv2.imshow("Harris Cornes", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
