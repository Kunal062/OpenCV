# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.preprocessing.image import ImageDataGenerator

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
plt.figure(figsize=(16,16))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.axis('off')
    plt.imshow(X_train[i],cmap='gray')
    plt.title(y_train[i])

# %% [markdown]
# ## ZCA Whitening

# %%
datagen = ImageDataGenerator(zca_whitening=True, featurewise_center=True)

# %%
X_train = X_train / 255

# %%
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# %%
datagen.fit(X_train)  # data generation

# %%
# Configure batch size and rerieve one batch of image
for x_batch, y_batch in datagen.flow(X_train, y_train, batch_size=25) :
    for i in range(0, 25) :
        # Create a grid of 5x5 images
        plt.subplot(5,5,i+1)
        plt.imshow(x_batch[i].reshape(28,28),cmap='gray')
    # Show the plot
    plt.show()
    break

# %% [markdown]
# ## Zooming

# %%
# define data preparation
datagen = ImageDataGenerator(zoom_range=0.6)

# %%
datagen.fit(X_train)

# %%
# Configure batch size and rerieve one batch of image
for x_batch, y_batch in datagen.flow(X_train, y_train, batch_size=25) :
    plt.figure(figsize=(16,16))
    for i in range(0, 25) :
        # Create a grid of 5x5 images
        plt.subplot(5,5,i+1)
        plt.imshow(x_batch[i].reshape(28,28),cmap='gray')
    # Show the plot
    plt.show()
    break

# %% [markdown]
# ## Flipping

# %%
# define data preparation
datagen = ImageDataGenerator(horizontal_flip=True,vertical_flip=True)

# %%
datagen.fit(X_train)

# %%
# Configure batch size and rerieve one batch of image
for x_batch, y_batch in datagen.flow(X_train, y_train, batch_size=25) :
    plt.figure(figsize=(16,16))
    for i in range(0, 25) :
        # Create a grid of 5x5 images
        plt.subplot(5,5,i+1)
        plt.imshow(x_batch[i].reshape(28,28),cmap='gray')
    # Show the plot
    plt.show()
    break

# %% [markdown]
# ## Random Rotation

# %%
# define data preparation
datagen = ImageDataGenerator(rotation_range=0.25)

# %%
datagen.fit(X_train)

# %%
# Configure batch size and rerieve one batch of image
for x_batch, y_batch in datagen.flow(X_train, y_train, batch_size=25) :
    plt.figure(figsize=(16,16))
    for i in range(0, 25) :
        # Create a grid of 5x5 images
        plt.subplot(5,5,i+1)
        plt.imshow(x_batch[i].reshape(28,28),cmap='gray')
    # Show the plot
    plt.show()
    break

# %% [markdown]
# ## Random Shearing

# %%
# define data preparation
datagen = ImageDataGenerator(shear_range=0.50) # Shear = Tilt

# %%
datagen.fit(X_train)

# %%
# Configure batch size and rerieve one batch of image
for x_batch, y_batch in datagen.flow(X_train, y_train, batch_size=25) :
    plt.figure(figsize=(16,16))
    for i in range(0, 25) :
        # Create a grid of 5x5 images
        plt.subplot(5,5,i+1)
        plt.imshow(x_batch[i].reshape(28,28),cmap='gray')
    # Show the plot
    plt.show()
    break

# %% [markdown]
# ## Random Translation / Shift

# %%
# define data preparation
datagen = ImageDataGenerator(width_shift_range=0.2,height_shift_range=0.2)
datagen.fit(X_train)
# Configure batch size and rerieve one batch of image
for x_batch, y_batch in datagen.flow(X_train, y_train, batch_size=25) :
    plt.figure(figsize=(16,16))
    for i in range(0, 25) :
        # Create a grid of 5x5 images
        plt.subplot(5,5,i+1)
        plt.imshow(x_batch[i].reshape(28,28),cmap='gray')
        plt.title(y_batch[i])
    # Show the plot
    plt.show()
    break
