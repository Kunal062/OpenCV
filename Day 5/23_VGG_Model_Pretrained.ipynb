# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16

# %%
image = load_img('adolf.webp', target_size=(224, 224))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image = img_to_array(image)

# %%
image

# %%
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

# %%
image.shape
# Out:
# (1, 224, 224, 3)

# %%
image = preprocess_input(image)

# %%
# Load the model
model = VGG16()

# %%
yhat = model.predict(image)
# Out:
# 1/1 [==============================] - 1s 903ms/step

# %%
yhat

# %%
len(yhat[0])
# Out:
# 1000

# %%
help(VGG16)

# %%
label = decode_predictions(yhat)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step

# %%
label
# Out:
# [[('n03763968', 'military_uniform', 0.56663257),
#   ('n02916936', 'bulletproof_vest', 0.054390006),
#   ('n04090263', 'rifle', 0.02111303),
#   ('n02536864', 'coho', 0.01997636),
#   ('n03942813', 'ping-pong_ball', 0.018894417)]]

# %%
image = load_img('sachin.jpg', target_size=(224, 224))
image = img_to_array(image)
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
image = preprocess_input(image)
yhat = model.predict(image)
label = decode_predictions(yhat)
label
# Out:
# 1/1 [==============================] - 1s 943ms/step
# [[('n09835506', 'ballplayer', 0.6465364),
#   ('n03379051', 'football_helmet', 0.26789898),
#   ('n02799071', 'baseball', 0.06059955),
#   ('n03127747', 'crash_helmet', 0.008224646),
#   ('n03623198', 'knee_pad', 0.0074688257)]]
